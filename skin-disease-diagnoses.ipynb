# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# Define paths for train and test folders
train_path = "/kaggle/input/skin-disease-dataset/skin-disease-datasaet/train_set/"
test_path = "/kaggle/input/skin-disease-dataset/skin-disease-datasaet/test_set/"

# List the contents of the Train and Test directories
print("Train Classes:", os.listdir(train_path))
print("Test Classes:", os.listdir(test_path))
# Out:
# Train Classes: ['FU-nail-fungus', 'FU-ringworm', 'VI-shingles', 'BA-impetigo', 'FU-athlete-foot', 'VI-chickenpox', 'PA-cutaneous-larva-migrans', 'BA- cellulitis']
# Test Classes: ['FU-nail-fungus', 'FU-ringworm', 'VI-shingles', 'BA-impetigo', 'FU-athlete-foot', 'VI-chickenpox', 'PA-cutaneous-larva-migrans', 'BA- cellulitis']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Function to count images in each class
def count_images(directory):
    class_counts = {}
    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if os.path.isdir(class_path):
            class_counts[class_name] = len(os.listdir(class_path))
    return class_counts

train_class_counts = count_images(train_path)
test_class_counts = count_images(test_path)

# Convert to DataFrames for easier plotting
train_df = pd.DataFrame(list(train_class_counts.items()), columns=['Class', 'Count'])
test_df = pd.DataFrame(list(test_class_counts.items()), columns=['Class', 'Count'])

# Plot Train and Test class distributions
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
sns.barplot(x='Class', y='Count', data=train_df, ax=ax[0])
ax[0].set_title("Train Set Class Distribution")
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=45)

sns.barplot(x='Class', y='Count', data=test_df, ax=ax[1])
ax[1].set_title("Test Set Class Distribution")
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45)

plt.tight_layout()
plt.show()

# %%
import random
from PIL import Image

def show_sample_images(directory, num_classes=8):
    classes = os.listdir(directory)
    fig, axes = plt.subplots(1, num_classes, figsize=(15, 20))

    # Flatten axes array to make indexing easier
    axes = axes.flatten()

    for i, class_name in enumerate(classes[:num_classes]):
        class_path = os.path.join(directory, class_name)
        img_name = random.choice(os.listdir(class_path))
        img_path = os.path.join(class_path, img_name)
        img = Image.open(img_path)
        axes[i].imshow(img)
        axes[i].set_title(class_name, rotation=45)  
        axes[i].axis('off')

    plt.tight_layout()  
    plt.show()

# Show sample images from Train set
show_sample_images(train_path)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import warnings

# Suppress all warnings
warnings.filterwarnings('ignore')

# %%
# Data Augmentation and Preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,          # Normalize pixel values
    shear_range=0.2,         # Random shear
    zoom_range=0.2,          # Random zoom
    #horizontal_flip=True,    # Flip images horizontally
    validation_split=0.15    # Split validation set
)

test_datagen = ImageDataGenerator(rescale=1./255)  # Just normalize for test data

# Load the Train and Validation datasets
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(224, 224),  # Resize images for AlexNet and SqueezeNet input size
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# Load the Test dataset
test_generator = test_datagen.flow_from_directory(
    test_path,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Get a batch of images and labels from the train_generator
augmented_images, labels = next(train_generator)

# Plot some of the images
def plot_augmented_images(images, labels, class_names, n=8):
    plt.figure(figsize=(12, 12))
    for i in range(n):
        plt.subplot(3, 3, i+1)
        img = images[i]
        label = labels[i]
        
        # Display the image
        plt.imshow(img)
        plt.title(class_names[np.argmax(label)])  # Get class name from one-hot encoded label
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# Getting class names from the generator
class_names = list(train_generator.class_indices.keys())

# Show the augmented images
plot_augmented_images(augmented_images, labels, class_names)
# Out:
# Found 788 images belonging to 8 classes.
# Found 136 images belonging to 8 classes.
# Found 233 images belonging to 8 classes.

# %%
def create_alexnet_model():
    model = models.Sequential()

    # 1st Convolutional Layer
    model.add(layers.Conv2D(96, (11, 11), strides=4, input_shape=(224, 224, 3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(3, 3), strides=2))

    # 2nd Convolutional Layer
    model.add(layers.Conv2D(256, (5, 5), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D(pool_size=(3, 3), strides=2))

    # 3rd, 4th, 5th Convolutional Layers
    model.add(layers.Conv2D(384, (3, 3), activation='relu', padding='same'))
    model.add(layers.Conv2D(384, (3, 3), activation='relu', padding='same'))
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D(pool_size=(3, 3), strides=2))

    # Flatten Layer
    model.add(layers.Flatten())

    # 1st Fully Connected Layer
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))

    # 2nd Fully Connected Layer
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))

    # Output Layer (8 classes for 8 skin infections)
    model.add(layers.Dense(8, activation='softmax'))

    return model

# %%
alexnet_model = create_alexnet_model()
alexnet_model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history_alexnet = alexnet_model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs= 50 
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729422317.723968     125 service.cc:145] XLA service 0x7de324003810 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729422317.724025     125 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1729422317.724030     125 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#  2/24 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2031 - loss: 2.0710
# I0000 00:00:1729422326.168415     125 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 30s 681ms/step - accuracy: 0.1422 - loss: 2.0804 - val_accuracy: 0.1484 - val_loss: 2.0584
# Epoch 2/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.1562 - loss: 2.0668 - val_accuracy: 0.1250 - val_loss: 2.0628
# Epoch 3/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 331ms/step - accuracy: 0.1339 - loss: 2.0719 - val_accuracy: 0.1484 - val_loss: 2.0614
# Epoch 4/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 2.0707 - val_accuracy: 0.1250 - val_loss: 2.0652
# Epoch 5/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 338ms/step - accuracy: 0.1541 - loss: 2.0472 - val_accuracy: 0.1328 - val_loss: 2.0463
# Epoch 6/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1875 - loss: 2.0331 - val_accuracy: 0.1250 - val_loss: 2.0363
# Epoch 7/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 345ms/step - accuracy: 0.1441 - loss: 2.0169 - val_accuracy: 0.2812 - val_loss: 1.9277
# Epoch 8/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2500 - loss: 1.9452 - val_accuracy: 0.2500 - val_loss: 1.9386
# Epoch 9/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 333ms/step - accuracy: 0.2952 - loss: 1.9154 - val_accuracy: 0.3828 - val_loss: 1.7732
# Epoch 10/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3750 - loss: 1.7287 - val_accuracy: 0.2500 - val_loss: 1.9367
# Epoch 11/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 336ms/step - accuracy: 0.3135 - loss: 1.7284 - val_accuracy: 0.3047 - val_loss: 1.6802
# Epoch 12/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3438 - loss: 1.6187 - val_accuracy: 0.7500 - val_loss: 0.9973
# Epoch 13/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 339ms/step - accuracy: 0.3748 - loss: 1.5646 - val_accuracy: 0.4141 - val_loss: 1.5758
# Epoch 14/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3125 - loss: 1.9077 - val_accuracy: 0.2500 - val_loss: 1.7695
# Epoch 15/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 335ms/step - accuracy: 0.4264 - loss: 1.4493 - val_accuracy: 0.4453 - val_loss: 1.5805
# Epoch 16/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4375 - loss: 1.3165 - val_accuracy: 0.1250 - val_loss: 1.8830
# Epoch 17/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 331ms/step - accuracy: 0.4534 - loss: 1.3824 - val_accuracy: 0.4766 - val_loss: 1.4819
# Epoch 18/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5938 - loss: 1.1221 - val_accuracy: 0.5000 - val_loss: 1.3593
# Epoch 19/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 334ms/step - accuracy: 0.5300 - loss: 1.2701 - val_accuracy: 0.4375 - val_loss: 1.4860
# Epoch 20/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6875 - loss: 1.0974 - val_accuracy: 0.6250 - val_loss: 1.2038
# Epoch 21/50
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 331ms/step - accuracy: 0
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras import layers, models

# Define the input shape based on your image size
input_shape = (224, 224, 3)

# Load the InceptionResNetV2 model
base_model = InceptionResNetV2(include_top=False, weights='imagenet', input_shape=input_shape)

# Freeze the base model layers
for layer in base_model.layers:
    layer.trainable = False

# Build the full model
model = models.Sequential()
model.add(base_model)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(8, activation='softmax'))  # 8 output classes

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_resnet_v2             │ ?                      │    54,336,736 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ ?                      │   0 (unbuilt) │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,336,736 (207.28 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 54,336,736 (207.28 MB)

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=40
)
# Out:
# Epoch 1/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.2694 - loss: 2.0637 - val_accuracy: 0.5859 - val_loss: 1.1582
# Epoch 2/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 313ms/step - accuracy: 0.5938 - loss: 1.1122 - val_accuracy: 0.8750 - val_loss: 0.8580
# Epoch 3/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 373ms/step - accuracy: 0.6966 - loss: 0.9386 - val_accuracy: 0.7734 - val_loss: 0.7048
# Epoch 4/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7500 - loss: 0.6545 - val_accuracy: 0.7500 - val_loss: 0.6405
# Epoch 5/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 386ms/step - accuracy: 0.8077 - loss: 0.6501 - val_accuracy: 0.8359 - val_loss: 0.5592
# Epoch 6/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8750 - loss: 0.4921 - val_accuracy: 0.8750 - val_loss: 0.3569
# Epoch 7/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 375ms/step - accuracy: 0.8706 - loss: 0.4871 - val_accuracy: 0.8516 - val_loss: 0.5579
# Epoch 8/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8438 - loss: 0.4670 - val_accuracy: 1.0000 - val_loss: 0.3572
# Epoch 9/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 379ms/step - accuracy: 0.8860 - loss: 0.4088 - val_accuracy: 0.8125 - val_loss: 0.5199
# Epoch 10/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8750 - loss: 0.3781 - val_accuracy: 1.0000 - val_loss: 0.0935
# Epoch 11/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 374ms/step - accuracy: 0.9174 - loss: 0.3436 - val_accuracy: 0.8984 - val_loss: 0.3824
# Epoch 12/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9375 - loss: 0.2418 - val_accuracy: 1.0000 - val_loss: 0.2097
# Epoch 13/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 368ms/step - accuracy: 0.9358 - loss: 0.2940 - val_accuracy: 0.8750 - val_loss: 0.4281
# Epoch 14/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9375 - loss: 0.3147 - val_accuracy: 1.0000 - val_loss: 0.1536
# Epoch 15/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 375ms/step - accuracy: 0.9426 - loss: 0.2611 - val_accuracy: 0.9062 - val_loss: 0.3788
# Epoch 16/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.2218 - val_accuracy: 0.8750 - val_loss: 0.2665
# Epoch 17/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 356ms/step - accuracy: 0.9658 - loss: 0.2219 - val_accuracy: 0.9062 - val_loss: 0.3537
# Epoch 18/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9375 - loss: 0.2504 - val_accuracy: 0.6250 - val_loss: 0.7644
# Epoch 19/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 356ms/step - accuracy: 0.9486 - loss: 0.2200 - val_accuracy: 0.8750 - val_loss: 0.3541
# Epoch 20/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1593 - val_accuracy: 0.8750 - val_loss: 0.4118
# Epoch 21/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 12s 376ms/step - accuracy: 0.9732 - loss: 0.1913 - val_accuracy: 0.9141 - val_loss: 0.3391
# Epoch 22/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9688 - loss: 0.2251 - val_accuracy: 0.8750 - val_loss: 0.4603
# Epoch 23/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 371ms/step - accuracy: 0.9516 - loss: 0.1960 - val_accuracy: 0.8828 - val_loss: 0.3546
# Epoch 24/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1626 - val_accuracy: 1.0000 - val_loss: 0.1412
# Epoch 25/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 369ms/step - accuracy: 0.9611 - loss: 0.1705 - val_accuracy: 0.8828 - val_loss: 0.3374
# Epoch 26/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9688 - loss: 0.1560 - val_accuracy: 1.0000 - val_loss: 0.0397
# Epoch 27/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 360ms/step - accuracy: 0.9755 - loss: 0.1544 - val_accuracy: 0.9062 - val_loss: 0.3277
# Epoch 28/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1335 - val_accuracy: 1.0000 - val_loss: 0.1758
# Epoch 29/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 357ms/step - accuracy: 0.9712 - loss: 0.1441 - val_accuracy: 0.9375 - val_loss: 0.2753
# Epoch 30/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9688 - loss: 0.1186 - val_accuracy: 0.7500 - val_loss: 0.5779
# Epoch 31/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 368ms/step - accuracy: 0.9836 - loss: 0.1360 - val_accuracy: 0.9375 - val_loss: 0.2756
# Epoch 32/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0659 - val_accuracy: 1.0000 - val_loss: 0.1508
# Epoch 33/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 354ms/step - accuracy: 0.9714 - loss: 0.1345 - val_accuracy: 0.9375 - val_loss: 0.2755
# Epoch 34/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0700 - val_accuracy: 0.7500 - val_loss: 0.4385
# Epoch 35/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 371ms/step - accuracy: 0.9738 - loss: 0.1387 - val_accuracy: 0.9141 - val_loss: 0.3044
# Epoch 36/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0973 - val_accuracy: 0.7500 - val_loss: 0.4794
# Epoch 37/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 367ms/step - accuracy: 0.9819 - loss: 0.1160 - val_accuracy: 0.9219 - val_loss: 0.3162
# Epoch 38/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0532 - val_accuracy: 1.0000 - val_loss: 0.0691
# Epoch 39/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 358ms/step - accuracy: 0.9813 - loss: 0.1090 - val_accuracy: 0.9062 - val_loss: 0.2895
# Epoch 40/40
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.1141 - val_accuracy: 1.0000 - val_loss: 0.0663

# %%
# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(test_generator)
print("Test Accuracy:", test_acc)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.9184 - loss: 0.2350
# Test Accuracy: 0.9270386099815369

# %%
import numpy as np
import tensorflow as tf

# Load and preprocess the image
def load_and_preprocess_image(image_path):
    img = tf.keras.utils.load_img(image_path, target_size=(224, 224))  # Use AlexNet's input size
    img_array = tf.keras.utils.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Normalize to [0, 1]
    return img_array

# Specify the path to your test image
test_image_path = '/kaggle/input/skin-disease-dataset/skin-disease-datasaet/test_set/VI-shingles/100_VI-shingles (27).jpg'  # Update this path

# Load the test image
test_image = load_and_preprocess_image(test_image_path)

# Make a prediction using AlexNet
predictions = alexnet_model.predict(test_image)

# Get the predicted class
predicted_class = np.argmax(predictions, axis=1)

# Assuming class_names is a list containing the names of your classes
print(f"Predicted class: {class_names[predicted_class[0]]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted class: VI-shingles

# %%
import numpy as np
import tensorflow as tf

# Load and preprocess the image
def load_and_preprocess_image(image_path):
    img = tf.keras.utils.load_img(image_path, target_size=(224, 224))  # Use InceptionResNetV2's input size
    img_array = tf.keras.utils.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Normalize to [0, 1]
    return img_array

# Specify the path to your test image
test_image_path = '/kaggle/input/skin-disease-dataset/skin-disease-datasaet/test_set/FU-ringworm/31_FU-ringworm (62).jpg'  # Update this path

# Load the test image
test_image = load_and_preprocess_image(test_image_path)

# Make a prediction using InceptionResNetV2
predictions = model.predict(test_image)  # Use the Inception model reference

# Get the predicted class
predicted_class = np.argmax(predictions, axis=1)

# Assuming class_names is a list containing the names of your classes
print(f"Predicted class: {class_names[predicted_class[0]]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted class: FU-ringworm
